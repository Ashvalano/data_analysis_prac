# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/btc-eth-prices-outliers.csv', index_col = ('Timestamp'), parse_dates = True)
# df.head()
# df.info

# locate null values in Ether column
# df.loc[df['Ether'].isnull()]

nan_rows = df[df.isnull().any(axis=1)]
nan_rows.head()
# Out:
#                  Bitcoin  Ether
# Timestamp
# 2017-12-08  16007.436667    NaN
# 2017-12-09  15142.834152    NaN
# 2017-12-10  14869.805000    NaN

# %%
df.loc['2017-12-07' : '2017-12-11'].fillna(method = 'bfill', inplace=True)
temp = df.loc['2017-12-07' : '2017-12-11']

# df.info()
temp.head()

df.plot(figsize=(16,9))
# Out:
# C:\Users\jc\AppData\Local\Temp\ipykernel_6700\2465673410.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc['2017-12-07' : '2017-12-11'].fillna(method = 'bfill', inplace=True)
# <Axes: xlabel='Timestamp'>

# %%
temp = df.loc['2017-12-15':'2017-12-30']
# 2017-12-28 is the anomaly

temp2 = df.loc['2018-03-01':'2018-03-15']
# 2018-03-04 is the anomaly

temp.plot(figsize=(16,9))
# Out:
# <Axes: xlabel='Timestamp'>

# %%
# df.reset_index(drop=True, inplace=True)
# df.set_index('Timestamp')

# df.head()

# parse_dates = true for these methods to work
dfClean = df.drop(['2017-12-28', '2018-03-04'])

# this also works, parse_dates = true for these methods to work
# dfClean = df.drop(pd.to_datetime(['2017-12-28', '2018-03-04']))
# df.drop(pd.to_datetime(['2017-12-28', '2018-03-04']))

# dfClean = df[~df.index.isin(pd.to_datetime(['2017-12-28', '2018-03-04']))]

dfClean.info()
dfClean.plot(figsize = (16,9))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 363 entries, 2017-04-02 to 2018-04-01
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Bitcoin  363 non-null    float64
#  1   Ether    363 non-null    float64
# dtypes: float64(2)
# memory usage: 8.5 KB
# <Axes: xlabel='Timestamp'>
